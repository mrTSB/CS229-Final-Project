# %%
pip install torch
# Out:
# ...
#
# ...
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# ...
#    ---------------------------------------- 0.0/204.1 MB ? eta -:--:--
#    ---------------------------------------- 2.4/204.1 MB 12.2 MB/s eta 0:00:17
#     --------------------------------------- 5.0/204.1 MB 12.6 MB/s eta 0:00:16
#    - -------------------------------------- 6.8/204.1 MB 11.6 MB/s eta 0:00:17
#    - -------------------------------------- 9.2/204.1 MB 11.2 MB/s eta 0:00:18
#    -- ------------------------------------- 11.0/204.1 MB 10.6 MB/s eta 0:00:19
#    -- ------------------------------------- 13.6/204.1 MB 11.0 MB/s eta 0:00:18
#    --- ------------------------------------ 16.0/204.1 MB 11.2 MB/s eta 0:00:17
#    --- ------------------------------------ 18.6/204.1 MB 11.3 MB/s eta 0:00:17
#    ---- ----------------------------------- 21.5/204.1 MB 11.6 MB/s eta 0:00:16
#    ---- ----------------------------------- 23.9/204.1 MB 11.6 MB/s eta 0:00:16
# ...

# %%
import torch

# Load the tensor from the file
tensor = torch.load('baseline.pt')

# Print the shape of the tensor
print(tensor.shape)
# Out:
# torch.Size([1212, 3])
