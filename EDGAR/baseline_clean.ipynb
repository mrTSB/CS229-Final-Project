# %%
import os
import numpy as np

# 1. Get the current working directory
current_dir = os.getcwd()

# Load the memory-mapped tensor
super_tensor_file = os.path.join(current_dir, "kernelized_tensor.npy")
molecule_types = ["CH4", "CO2", "CO2bio", "GWP", "N2O"]
data_types = ["emi", "flx"]

# Load the super tensor
super_tensor_shape = (5, 2, 288, 600, 1200)
kernelized_tensor = np.memmap(super_tensor_file, dtype='float32', mode='r', shape=super_tensor_shape)

print(kernelized_tensor.shape)
# Out:
# (5, 2, 288, 600, 1200)

# %%
import numpy as np
import tensorflow as tf
from tf.keras import layers, models
from tf.keras.optimizers import Adam
from tf.keras.callbacks import Callback
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt

# Optionally enable mixed precision if using GPUs
if tf.config.list_physical_devices('GPU'):
    tf.keras.mixed_precision.set_global_policy('mixed_float16')
    print("Mixed precision enabled")

# --- Data Dimensions ---
num_molecules = 5         # CH4, CO2, CO2bio, GWP, N2O
num_time = 288            # 12 months * 24 years
lat_full = 600            # Full kernelized latitude dimension
lon_full = 1200           # Full kernelized longitude dimension

# We'll work in a lower resolution:
low_res_h, low_res_w = 75, 150
output_channels = 5       # one channel per molecule

# --- Use preloaded tensor ---
# Assume 'kernelized_tensor' is loaded with shape (5, 2, 288, 600, 1200)
data = kernelized_tensor

# Select emissions only (data type index 0); resulting shape: (5, 288, 600, 1200)
data_emissions = data[:, 0, :, :, :]

# Rearrange dimensions so that time is first: (288, 5, 600, 1200)
emissions_data = np.transpose(data_emissions, (1, 0, 2, 3))

# Convert targets to float32 and reshape to (num_time, 5, 600, 1200)
Y_full = emissions_data.astype(np.float32).reshape(num_time, num_molecules, lat_full, lon_full)

# --- Downsample Targets ---
# Downsample from (600, 1200) to (75, 150) via block averaging.
# First, bring channels to the end: (num_time, 600, 1200, 5)
Y_full = np.transpose(Y_full, (0, 2, 3, 1))
Y_low = np.empty((num_time, low_res_h, low_res_w, output_channels), dtype=np.float32)
for i in range(num_time):
    # Assuming 600/75 = 8 and 1200/150 = 8, use block averaging.
    Y_low[i] = Y_full[i].reshape(low_res_h, 8, low_res_w, 8, output_channels).mean(axis=(1, 3))

# --- Log Transformation ---
# The raw values are very large. Applying a log1p transform compresses the range.
# We assume emissions are nonnegative.
Y_low_log = np.log1p(Y_low)

# --- Prepare Time Features and Train/Test Split ---
# Normalize the month index to [0,1]
X = (np.arange(num_time).reshape(-1, 1).astype(np.float32)) / (num_time - 1)

# Use the first 48 months for training and the next 12 for testing.
train_time = 48
test_time = 12
X_train = X[:train_time]
X_test = X[train_time:train_time + test_time]
Y_train = Y_low_log[:train_time]  # shape: (48, 75, 150, 5)
Y_test = Y_low_log[train_time:train_time + test_time]

print("Training samples:", X_train.shape[0])
print("Test samples:", X_test.shape[0])
print("Target (log-transformed) shape per sample:", Y_train.shape[1:])  # (75, 150, 5)

# --- Normalize Log-Transformed Targets ---
Y_train_mean = np.mean(Y_train, dtype=np.float32)
Y_train_std = np.std(Y_train, dtype=np.float32)
print("Y_train_mean (log scale):", Y_train_mean)
print("Y_train_std (log scale):", Y_train_std)

Y_train_norm = (Y_train - Y_train_mean) / Y_train_std
Y_test_norm = (Y_test - Y_train_mean) / Y_train_std

# --- Custom Callback for Progress Monitoring ---
class ProgressCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        loss = logs.get('loss')
        print(f"Epoch {epoch+1:03d}: Loss = {loss:.6f}")

progress_callback = ProgressCallback()

# --- Use MirroredStrategy for GPU Training ---
strategy = tf.distribute.MirroredStrategy()
print(f"Number of devices: {strategy.num_replicas_in_sync}")

with strategy.scope():
    # Build a model that predicts the low-resolution (log-transformed) target.
    model = models.Sequential([
        layers.Input(shape=(1,)),  # Input is a scalar (normalized month index)
        layers.Dense(64, activation='relu'),
        layers.Dense(128, activation='relu'),
        # Project to a vector that will be reshaped to (75, 150, 5)
        layers.Dense(low_res_h * low_res_w * output_channels, activation='relu'),
        layers.Reshape((low_res_h, low_res_w, output_channels))
    ])
    
    # Use a very low learning rate with gradient clipping.
    optimizer = Adam(learning_rate=1e-7, clipnorm=1.0)
    model.compile(optimizer=optimizer, loss='mse')
    model.summary()

print("X_train shape:", X_train.shape)
print("Y_train_norm shape:", Y_train_norm.shape)

# Check for NaN or infinite values
print("NaN in X_train:", np.isnan(X_train).any())
print("NaN in Y_train_norm:", np.isnan(Y_train_norm).any())
print("Infinite in X_train:", np.isinf(X_train).any())
print("Infinite in Y_train_norm:", np.isinf(Y_train_norm).any())


# --- Train the Model ---
history = model.fit(
    X_train, Y_train_norm,
    epochs=50,
    batch_size=1,  # Small batch size for memory efficiency
    verbose=0,
    callbacks=[progress_callback]
)

# --- Plot Training Loss History ---
plt.figure(figsize=(8, 4))
plt.plot(history.history['loss'], marker='o')
plt.xlabel('Epoch')
plt.ylabel('Training Loss (MSE)')
plt.title('Training Loss Progress')
plt.grid(True)
plt.show()

# --- Evaluate the Model ---
Y_pred_norm = model.predict(X_test)
test_mse_norm = mean_squared_error(Y_test_norm.flatten(), Y_pred_norm.flatten())
print("Test MSE (normalized):", test_mse_norm)

# --- Inverse Transform Predictions ---
# Invert the normalization:
Y_pred_log = Y_pred_norm * Y_train_std + Y_train_mean
# Invert the log transform: use expm1 to recover original scale (low resolution)
Y_pred = np.expm1(Y_pred_log)
Y_test_inv = np.expm1(Y_test_norm * Y_train_std + Y_train_mean)

# --- Compute Additional Metrics ---
mse = mean_squared_error(Y_test_inv.flatten(), Y_pred.flatten())
rmse = np.sqrt(mse)
mae = mean_absolute_error(Y_test_inv.flatten(), Y_pred.flatten())
r2 = r2_score(Y_test_inv.flatten(), Y_pred.flatten())
corr = np.corrcoef(Y_test_inv.flatten(), Y_pred.flatten())[0, 1]

print("MSE:", mse)
print("RMSE:", rmse)
print("MAE:", mae)
print("R^2:", r2)
print("Pearson correlation coefficient:", corr)

# --- Visualize a Sample Prediction ---
sample_idx = 0  # first test sample
molecule_idx = 0  # visualize for molecule 0

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.imshow(Y_test_inv[sample_idx, :, :, molecule_idx], cmap='viridis')
plt.title('Ground Truth (Molecule 0)')
plt.colorbar()

plt.subplot(1, 2, 2)
plt.imshow(Y_pred[sample_idx, :, :, molecule_idx], cmap='viridis')
plt.title('Prediction (Molecule 0)')
plt.colorbar()

plt.tight_layout()
plt.show()
# Out:
# Mixed precision enabled
# Training samples: 48
# Test samples: 12
# Target (log-transformed) shape per sample: (75, 150, 5)
# Y_train_mean (log scale): 0.19016193
# Y_train_std (log scale): 0.7214341
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0000 00:00:1741475547.194087 3382688 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43622 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:61:00.0, compute capability: 8.9
# Number of devices: 1
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 56250)          │     7,256,250 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 75, 150, 5)     │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,264,698 (27.71 MB)
#  Trainable params: 7,264,698 (27.71 MB)
#  Non-trainable params: 0 (0.00 B)
# X_train shape: (48, 1)
# Y_train_norm shape: (48, 75, 150, 5)
# NaN in X_train: False
# NaN in Y_train_norm: False
# Infinite in X_train: False
# Infinite in Y_train_norm: False
# 2025-03-08 15:12:28.531896: E tensorflow/core/util/util.cc:131] oneDNN supports DT_HALF only on platforms with AVX-512. Falling back to the default Eigen-based implementation if present.
# 2025-03-08 15:12:29.580124: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 2025-03-08 15:12:29.580210: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 	 [[RemoteCall]]
# Epoch 001: Loss = 0.999996
# 2025-03-08 15:12:29.821285: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 	 [[RemoteCall]]
# Epoch 002: Loss = 0.999994
# Epoch 003: Loss = 0.999991
# 2025-03-08 15:12:30.287929: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 	 [[RemoteCall]]
# Epoch 004: Loss = 0.999989
# Epoch 005: Loss = 0.999987
# Epoch 006: Loss = 0.999984
# Epoch 007: Loss = 0.999982
# 2025-03-08 15:12:31.215982: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 	 [[RemoteCall]]
# Epoch 008: Loss = 0.999979
# Epoch 009: Loss = 0.999977
# Epoch 010: Loss = 0.999975
# Epoch 011: Loss = 0.999972
# Epoch 012: Loss = 0.999970
# Epoch 013: Loss = 0.999968
# Epoch 014: Loss = 0.999965
# Epoch 015: Loss = 0.999963
# 2025-03-08 15:12:33.093774: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 	 [[RemoteCall]]
# Epoch 016: Loss = 0.999960
# Epoch 017: Loss = 0.999958
# Epoch 018: Loss = 0.999956
# Epoch 019: Loss = 0.999953
# Epoch 020: Loss = 0.999951
# Epoch 021: Loss = 0.999949
# Epoch 022: Loss = 0.999946
# Epoch 023: Loss = 0.999944
# Epoch 024: Loss = 0.999942
# Epoch 025: Loss = 0.999939
# Epoch 026: Loss = 0.999937
# Epoch 027: Loss = 0.999935
# Epoch 028: Loss = 0.999932
# Epoch 029: Loss = 0.999930
# Epoch 030: Loss = 0.999928
# Epoch 031: Loss = 0.999925
# 2025-03-08 15:12:36.906204: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 	 [[RemoteCall]]
# Epoch 032: Loss = 0.999923
# Epoch 033: Loss = 0.999921
# Epoch 034: Loss = 0.999919
# Epoch 035: Loss = 0.999916
# Epoch 036: Loss = 0.999914
# Epoch 037: Loss = 0.999912
# Epoch 038: Loss = 0.999910
# Epoch 039: Loss = 0.999907
# Epoch 040: Loss = 0.999905
# Epoch 041: Loss = 0.999903
# Epoch 042: Loss = 0.999901
# Epoch 043: Loss = 0.999898
# Epoch 044: Loss = 0.999896
# Epoch 045: Loss = 0.999894
# Epoch 046: Loss = 0.999892
# Epoch 047: Loss = 0.999889
# Epoch 048: Loss = 0.999887
# Epoch 049: Loss = 0.999885
# Epoch 050: Loss = 0.999883
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Test MSE (normalized): 1.021527886390686
# MSE: 1839.5123291015625
# RMSE: 42.88953635913499
# MAE: 3.224534034729004
# R^2: -0.004456996917724609
# Pearson correlation coefficient: 0.05375411958759114

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # Suppress INFO and WARNING messages
